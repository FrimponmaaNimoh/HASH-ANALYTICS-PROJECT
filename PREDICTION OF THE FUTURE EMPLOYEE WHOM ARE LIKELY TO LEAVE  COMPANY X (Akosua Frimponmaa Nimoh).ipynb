# %%
import pandas as pd

# %%
existing_employees=pd.read_csv("Existing Employee.csv",encoding= "Latin-1")

# %%
existing_employees.info()
#no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11428 entries, 0 to 11427
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Emp ID                 11428 non-null  int64
#  1   satisfaction_level     11428 non-null  float64
#  2   last_evaluation        11428 non-null  float64
#  3   number_project         11428 non-null  int64
#  4   average_montly_hours   11428 non-null  int64
#  5   time_spend_company     11428 non-null  int64
#  6   Work_accident          11428 non-null  int64
#  7   promotion_last_5years  11428 non-null  int64
#  8   dept                   11428 non-null  object
#  9   salary                 11428 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 892.9+ KB

# %% [markdown]
# #### FINDING EXISTING EMPLOYEES LIKELY TO LEAVE COMPANY X
#
# ##### Determining Factors
#
# 1) An employee within the sales,support,technical department.
#
# 2) An employee with low salary.
#
# 3) An employee with an average job satisfaction of 0.44.
#
# 4) An employee with no promotions after working 3-5 years.
#
# 5) An employee with 0 work accidents.

# %%
condition_1_bool= ((existing_employees["dept"]=="sales")|(existing_employees["dept"]=="support")|(existing_employees["dept"]=="technical")) & (existing_employees["salary"]=="low" ) & (existing_employees["promotion_last_5years"]==0)&(existing_employees["satisfaction_level"]<=0.44)&(existing_employees["Work_accident"]==0)&(existing_employees["time_spend_company"]==3)
likely_to_leave_employee = existing_employees.loc[condition_1_bool].sort_values("satisfaction_level").reset_index(drop=True)
likely_to_leave_employee
# Out:
#     Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0     9283                0.12             0.90               3
# 1     4324                0.13             0.76               5
# 2     7507                0.14             0.41               6
# 3     6881                0.14             0.71               2
# 4     9797                0.15             0.42               3
# ..     ...                 ...              ...             ...
# 82    4520                0.44             0.45               2
# 83    8664                0.44             0.58               4
# 84    5541                0.44             0.48               2
# 85    2868                0.44             0.68               3
# 86    7007                0.44             0.39               2
#
#     average_montly_hours  time_spend_company  Work_accident  \
# 0                    200                   3              0
# 1                    217                   3              0
# ...

# %%
likely_to_leave_employee.head(10)
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0    9283                0.12             0.90               3
# 1    4324                0.13             0.76               5
# 2    7507                0.14             0.41               6
# 3    6881                0.14             0.71               2
# 4    9797                0.15             0.42               3
# 5    8868                0.15             0.37               2
# 6    6587                0.15             0.74               6
# 7    9279                0.16             0.73               6
# 8    3561                0.16             0.88               6
# 9    2789                0.16             0.97               6
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   200                   3              0
# 1                   217                   3              0
# 2                   114                   3              0
# ...

# %%
likely_to_leave_employee['dept'].value_counts()
# Out:
# sales        41
# technical    24
# support      22
# Name: dept, dtype: int64

# %%
likely_to_leave_employee['time_spend_company'].value_counts()
# Out:
# 3    87
# Name: time_spend_company, dtype: int64

# %% [markdown]
# #### MOST PRONE TO LEAVE
#
# An employee surely within the sales department, with low salary , an average job satisfaction of 0.44 and has no promotions after working 3 years

# %%
most_prone_condition_bool= (likely_to_leave_employee["dept"]=="sales")
most_prone_to_leave_employee = likely_to_leave_employee.loc[most_prone_condition_bool].sort_values(["satisfaction_level","number_project"]).reset_index(drop=True)
most_prone_to_leave_employee
# Out:
#     Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0     6881                0.14             0.71               2
# 1     7507                0.14             0.41               6
# 2     8868                0.15             0.37               2
# 3     9797                0.15             0.42               3
# 4     6587                0.15             0.74               6
# 5     6201                0.17             0.51               5
# 6     6814                0.17             0.57               5
# 7     9564                0.19             0.73               4
# 8     3682                0.19             0.91               6
# 9     8792                0.20             0.98               2
# 10    4602                0.20             0.96               2
# 11    6280                0.23             0.97               4
# 12    7049                0.24             0.70               5
# 13    3917                0.25             0.97               3
# ...

# %%
most_prone_to_leave_employee.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0    6881                0.14             0.71               2
# 1    7507                0.14             0.41               6
# 2    8868                0.15             0.37               2
# 3    9797                0.15             0.42               3
# 4    6587                0.15             0.74               6
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   155                   3              0
# 1                   114                   3              0
# 2                   167                   3              0
# 3                    98                   3              0
# 4                   178                   3              0
#
#    promotion_last_5years   dept salary
# 0                      0  sales    low
# 1                      0  sales    low
# 2                      0  sales    low
# 3                      0  sales    low
# ...
